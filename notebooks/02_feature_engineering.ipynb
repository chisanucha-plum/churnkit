# %% [markdown]
# # Feature Engineering
#
# This notebook demonstrates feature engineering techniques for the churn prediction model.

# %%
import pandas as pd
import numpy as np
import sys
sys.path.insert(0, '..')

from app.services.feature_engineer import FeatureEngineer

# Load data
df = pd.read_csv('../data/raw/churn_data.csv')

# Initialize feature engineer
engineer = FeatureEngineer()

print(f"Original features: {df.shape[1]}")

# %% [markdown]
# ## Create Interaction Features

# %%
# Create interaction features
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
df = engineer.create_interaction_features(df, numeric_cols[:3])

print(f"Features after interaction: {df.shape[1]}")
